# %%
# %matplotlib widget
# if this errors: pip install ipympl, then restart the kernel

from label_court_notebook import label_court_corners_notebook
picker = label_court_corners_notebook("31")
# Out:
# [SKIP] /home/jovyan/hitnet/training/data/court/31.out already exists (pass overwrite=True to relabel).

# %%
picker.save()
# Out:
# [INFO] Saved /home/jovyan/hitnet/training/data/court/30.out
#   A (top-left): (414.1, 303.4)
#   D (top-right): (864.9, 301.7)
#   G (bottom-left): (290.2, 659.3)
#   X (bottom-right): (988.8, 657.7)
# PosixPath('/home/jovyan/hitnet/training/data/court/30.out')
